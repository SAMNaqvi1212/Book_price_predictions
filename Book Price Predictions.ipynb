# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import re

# %%
df=pd.read_excel("Data_Train.xlsx")

# %%
df.head()
# Out:
#                                         Title           Author  \
# 0         The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1          Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                Leviathan (Penguin Classics)    Thomas Hobbes
# 3          A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4  LIFE 70 Years of Extraordinary Photography  Editors of Life
#
#                    Edition             Reviews              Ratings  \
# 0  Paperback,– 10 Mar 2016  4.0 out of 5 stars   8 customer reviews
# 1   Paperback,– 7 Nov 2012  3.9 out of 5 stars  14 customer reviews
# 2  Paperback,– 25 Feb 1982  4.8 out of 5 stars   6 customer reviews
# 3   Paperback,– 5 Oct 2017  4.1 out of 5 stars  13 customer reviews
# 4  Hardcover,– 10 Oct 2006  5.0 out of 5 stars    1 customer review
#
#                                             Synopsis  \
# 0  THE HUNTERS return in their third brilliant no...
# 1  A layered portrait of a troubled genius for wh...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6237 entries, 0 to 6236
# Data columns (total 9 columns):
# Title           6237 non-null object
# Author          6237 non-null object
# Edition         6237 non-null object
# Reviews         6237 non-null object
# Ratings         6237 non-null object
# Synopsis        6237 non-null object
# Genre           6237 non-null object
# BookCategory    6237 non-null object
# Price           6237 non-null float64
# dtypes: float64(1), object(8)
# memory usage: 438.7+ KB

# %%
df.describe(include="all").head(2)
# Out:
#        Title Author Edition Reviews Ratings Synopsis Genre BookCategory  \
# count   6237   6237    6237    6237    6237     6237  6237         6237
# unique  5568   3679    3370      36     342     5549   345           11
#
#          Price
# count   6237.0
# unique     NaN

# %%
df["Reviews"]
# Out:
# 0       4.0 out of 5 stars
# 1       3.9 out of 5 stars
# 2       4.8 out of 5 stars
# 3       4.1 out of 5 stars
# 4       5.0 out of 5 stars
#                ...
# 6232    5.0 out of 5 stars
# 6233    3.3 out of 5 stars
# 6234    3.8 out of 5 stars
# 6235    3.5 out of 5 stars
# 6236    3.9 out of 5 stars
# Name: Reviews, Length: 6237, dtype: object

# %%
df["Genre"].nunique()
# Out:
# 345

# %%
def data(x):
    for i in x:
         i=x.split(" ")[0]
    return i

# %%
df["Reviews"]=df["Reviews"].apply(data)

# %%
df["Reviews"]=df["Reviews"].astype("float16")

# %%
df.head(5)
# Out:
#                                         Title           Author  \
# 0         The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1          Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                Leviathan (Penguin Classics)    Thomas Hobbes
# 3          A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4  LIFE 70 Years of Extraordinary Photography  Editors of Life
#
#                    Edition   Reviews              Ratings  \
# 0  Paperback,– 10 Mar 2016  4.000000   8 customer reviews
# 1   Paperback,– 7 Nov 2012  3.900391  14 customer reviews
# 2  Paperback,– 25 Feb 1982  4.800781   6 customer reviews
# 3   Paperback,– 5 Oct 2017  4.101562  13 customer reviews
# 4  Hardcover,– 10 Oct 2006  5.000000    1 customer review
#
#                                             Synopsis  \
# 0  THE HUNTERS return in their third brilliant no...
# 1  A layered portrait of a troubled genius for wh...
# 2  "During the time men live without a common Pow...
# ...

# %%
#

# %%
def data_1(x):
    for i in x:
         i=x.split(" ")[0]
    return i

# %%
df["Number of Ratings"]=df["Ratings"].apply(data_1)

# %%
df.head(2)
# Out:
#                                  Title          Author  \
# 0  The Prisoner's Gold (The Hunters 3)  Chris Kuzneski
# 1   Guru Dutt: A Tragedy in Three Acts    Arun Khopkar
#
#                    Edition   Reviews              Ratings  \
# 0  Paperback,– 10 Mar 2016  4.000000   8 customer reviews
# 1   Paperback,– 7 Nov 2012  3.900391  14 customer reviews
#
#                                             Synopsis  \
# 0  THE HUNTERS return in their third brilliant no...
# 1  A layered portrait of a troubled genius for wh...
#
#                         Genre                          BookCategory   Price  \
# 0  Action & Adventure (Books)                    Action & Adventure  220.00
# 1  Cinema & Broadcast (Books)  Biographies, Diaries & True Accounts  202.93
#
#   Number of Ratings
# 0                 8
# 1                14

# %%
def extract(x):
    for i in x:
         i=x.split(",")[0]
    return i

# %%
df["Edition_1"]=df["Edition"].apply(extract)

# %%
df.head(2)
# Out:
#                                  Title          Author  \
# 0  The Prisoner's Gold (The Hunters 3)  Chris Kuzneski
# 1   Guru Dutt: A Tragedy in Three Acts    Arun Khopkar
#
#                    Edition   Reviews              Ratings  \
# 0  Paperback,– 10 Mar 2016  4.000000   8 customer reviews
# 1   Paperback,– 7 Nov 2012  3.900391  14 customer reviews
#
#                                             Synopsis  \
# 0  THE HUNTERS return in their third brilliant no...
# 1  A layered portrait of a troubled genius for wh...
#
#                         Genre                          BookCategory   Price  \
# 0  Action & Adventure (Books)                    Action & Adventure  220.00
# 1  Cinema & Broadcast (Books)  Biographies, Diaries & True Accounts  202.93
#
#   Number of Ratings  Edition_1
# 0                 8  Paperback
# 1                14  Paperback

# %%
def second_extract(x):
    for i in x:
         i=x.strip(" ")[11:23]
    return i

# %%
df["Date"]=df["Edition"].apply(second_extract)

# %%
df["Date"]
# Out:
# 0        10 Mar 2016
# 1         7 Nov 2012
# 2        25 Feb 1982
# 3         5 Oct 2017
# 4        10 Oct 2006
#             ...
# 6232      8 Aug 2018
# 6233     21 Nov 2016
# 6234      8 Jun 2006
# 6235     15 Jan 2015
# 6236     21 Dec 2016
# Name: Date, Length: 6237, dtype: object

# %%
df.head(2)
# Out:
#                                  Title          Author  \
# 0  The Prisoner's Gold (The Hunters 3)  Chris Kuzneski
# 1   Guru Dutt: A Tragedy in Three Acts    Arun Khopkar
#
#                    Edition   Reviews              Ratings  \
# 0  Paperback,– 10 Mar 2016  4.000000   8 customer reviews
# 1   Paperback,– 7 Nov 2012  3.900391  14 customer reviews
#
#                                             Synopsis  \
# 0  THE HUNTERS return in their third brilliant no...
# 1  A layered portrait of a troubled genius for wh...
#
#                         Genre                          BookCategory   Price  \
# 0  Action & Adventure (Books)                    Action & Adventure  220.00
# 1  Cinema & Broadcast (Books)  Biographies, Diaries & True Accounts  202.93
#
#   Number of Ratings  Edition_1          Date
# 0                 8  Paperback   10 Mar 2016
# 1                14  Paperback    7 Nov 2012

# %%
df.head(10)
# Out:
#                                                Title  \
# 0                The Prisoner's Gold (The Hunters 3)
# 1                 Guru Dutt: A Tragedy in Three Acts
# 2                       Leviathan (Penguin Classics)
# 3                 A Pocket Full of Rye (Miss Marple)
# 4         LIFE 70 Years of Extraordinary Photography
# 5  ChiRunning: A Revolutionary Approach to Effort...
# 6                         Death on the Nile (Poirot)
# 7  Yoga Your Home Practice Companion: A Complete ...
# 8            Karmayogi: A Biography of E. Sreedharan
# 9         The Iron King (The Accursed Kings, Book 1)
#
#                           Author                         Edition   Reviews  \
# 0                 Chris Kuzneski         Paperback,– 10 Mar 2016  4.000000
# 1                   Arun Khopkar          Paperback,– 7 Nov 2012  3.900391
# 2                  Thomas Hobbes         Paperback,– 25 Feb 1982  4.800781
# 3                Agatha Christie          Paperback,– 5 Oct 2017  4.101562
# ...

# %%
df["Number of Ratings"].tail(5)
# Out:
# 6232    2
# 6233    9
# 6234    3
# 6235    4
# 6236    2
# Name: Number of Ratings, dtype: object

# %%
ratings=list(df["Number of Ratings"])
plu=","
ratings=[int(re.sub(",","",i).strip()) for i in ratings]

# %%
ratings[735]
# Out:
# 1558

# %%
df["Number of Ratings"]=ratings

# %%
df["Number of Ratings"]
# Out:
# 0        8
# 1       14
# 2        6
# 3       13
# 4        1
#         ..
# 6232     2
# 6233     9
# 6234     3
# 6235     4
# 6236     2
# Name: Number of Ratings, Length: 6237, dtype: int64

# %%
df.head(5)
# Out:
#                                         Title           Author  \
# 0         The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1          Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                Leviathan (Penguin Classics)    Thomas Hobbes
# 3          A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4  LIFE 70 Years of Extraordinary Photography  Editors of Life
#
#                    Edition   Reviews              Ratings  \
# 0  Paperback,– 10 Mar 2016  4.000000   8 customer reviews
# 1   Paperback,– 7 Nov 2012  3.900391  14 customer reviews
# 2  Paperback,– 25 Feb 1982  4.800781   6 customer reviews
# 3   Paperback,– 5 Oct 2017  4.101562  13 customer reviews
# 4  Hardcover,– 10 Oct 2006  5.000000    1 customer review
#
#                                             Synopsis  \
# 0  THE HUNTERS return in their third brilliant no...
# 1  A layered portrait of a troubled genius for wh...
# 2  "During the time men live without a common Pow...
# ...

# %%
df["year"]=df['Edition'].str.split().str[-1].str.strip()

# %%
df["year"].head(55)
# Out:
# 0     2016
# 1     2012
# 2     1982
# 3     2017
# 4     2006
# 5     2009
# 6     2017
# 7     2018
# 8     2015
# 9     2013
# 10    2017
# 11    2018
# 12    1999
# 13    2002
# 14    2011
# 15    2015
# 16    2018
# 17    2016
# 18    1991
# 19    2016
# 20    2018
# 21    2018
# 22    2012
# 23    2014
# 24    2012
# 25    2011
# 26    2016
# 27    2014
# 28    2014
# 29    1989
# 30    2013
# 31    2015
# 32    2000
# 33    2005
# 34    2016
# 35    2019
# 36    2014
# 37    2009
# 38    2006
# 39    2013
# 40    2013
# 41    2013
# 42    2008
# 43    2015
# 44    2019
# 45    2014
# 46    2006
# 47    2014
# 48    2012
# 49    2012
# 50    2017
# 51    2016
# 52    2018
# 53    2000
# 54    2018
# Name: year, dtype: object

# %%
df["month"]=df['Edition'].str.split().str[-2].str.strip()

# %%
df["month"]
# Out:
# 0       Mar
# 1       Nov
# 2       Feb
# 3       Oct
# 4       Oct
#        ...
# 6232    Aug
# 6233    Nov
# 6234    Jun
# 6235    Jan
# 6236    Dec
# Name: month, Length: 6237, dtype: object

# %%
months =['Apr','Aug','Dec','Feb', 'Jan', 'Jul','Jun','Mar','May','Nov','Oct','Sep']
def remove_text(names):
        if names in months:
            names=names.upper()
        else:
            names="NA"
        return names

# %%
df["month"]=df["month"].apply(remove_text)

# %%
df.head(5)
# Out:
#                                         Title           Author  \
# 0         The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1          Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                Leviathan (Penguin Classics)    Thomas Hobbes
# 3          A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4  LIFE 70 Years of Extraordinary Photography  Editors of Life
#
#                    Edition   Reviews              Ratings  \
# 0  Paperback,– 10 Mar 2016  4.000000   8 customer reviews
# 1   Paperback,– 7 Nov 2012  3.900391  14 customer reviews
# 2  Paperback,– 25 Feb 1982  4.800781   6 customer reviews
# 3   Paperback,– 5 Oct 2017  4.101562  13 customer reviews
# 4  Hardcover,– 10 Oct 2006  5.000000    1 customer review
#
#                                             Synopsis  \
# 0  THE HUNTERS return in their third brilliant no...
# 1  A layered portrait of a troubled genius for wh...
# 2  "During the time men live without a common Pow...
# ...

# %%
def remove_unnecessary(Year):
    if Year.isdigit():
        Year=int(Year)
    else:
        Year=0
    return Year

# %%
df["year"].head(55)
# Out:
# 0     2016
# 1     2012
# 2     1982
# 3     2017
# 4     2006
# 5     2009
# 6     2017
# 7     2018
# 8     2015
# 9     2013
# 10    2017
# 11    2018
# 12    1999
# 13    2002
# 14    2011
# 15    2015
# 16    2018
# 17    2016
# 18    1991
# 19    2016
# 20    2018
# 21    2018
# 22    2012
# 23    2014
# 24    2012
# 25    2011
# 26    2016
# 27    2014
# 28    2014
# 29    1989
# 30    2013
# 31    2015
# 32    2000
# 33    2005
# 34    2016
# 35    2019
# 36    2014
# 37    2009
# 38    2006
# 39    2013
# 40    2013
# 41    2013
# 42    2008
# 43    2015
# 44    2019
# 45    2014
# 46    2006
# 47    2014
# 48    2012
# 49    2012
# 50    2017
# 51    2016
# 52    2018
# 53    2000
# 54    2018
# Name: year, dtype: object

# %%
author_names=df["Author"]

# %%
author_names=list(author_names)

# %%
author_slice=[i.split(",") for i in author_names]

# %%
max=1
for i in author_slice:
    if len(i)>=max:
        max=len(i)
print("Number of authors for a single book:",max)
all_authors = [cat.strip().upper() for listin in author_slice for cat in listin]
# Out:
# Number of authors for a single book: 5

# %%
author_name=(df["Author"])
author_name=list(author_name)
authorslis_1=[i.split(",") for i in author_name]
max = 1
for i in authorslis_1:
    if len(i) >= max:
        max = len(i)
print("Max. number of authors for a single boook = ",max)

for i in range(len(authorslis_1)):
    if len(authorslis_1[i]) == max:
        print(i)    
    
all_authors = [author.strip().upper() for listin in authorslis_1 for author in listin]
# Out:
# Max. number of authors for a single boook =  5
# 77
# 1334
# 1915
# 2343

# %%
all_authors
# Out:
# ['CHRIS KUZNESKI',
#  'ARUN KHOPKAR',
#  'THOMAS HOBBES',
#  'AGATHA CHRISTIE',
#  'EDITORS OF LIFE',
#  'DANNY DREYER',
#  'AGATHA CHRISTIE',
#  'SIVANANDA YOGA VEDANTA CENTRE',
#  'M S ASHOKAN',
#  'MAURICE DRUON',
#  'RAJIV MALHOTRA',
#  'DON TAPSCOTT',
#  'ALEX TAPSCOTT',
#  'JAMES CLAVELL',
#  'WONG KIEW KIT',
#  'MICHAEL ONDAATJE',
#  'MATTHEW K MANNING',
#  'CHARLOTTE GUILLAIN',
#  'ROLAND DRY',
#  'TAKASHI YANO',
#  'WILL DURANT',
#  'DAVY CIELEN',
#  'ARNO D.B. MEYSMAN',
#  'MOHAMED ALI',
#  'HIRO ARIKAWA',
#  'LUCA CAIOLI',
#  'MARIO PUZO',
#  'MURUGESAN RAMASWAMY',
#  'JENNY RUSS',
#  'ROBERT NEUWIRTH',
#  'SHANTANU GUHA RAY',
#  'OSAMU TEZUKA',
#  'BRIAN SHIELDS',
#  'C. G. JUNG',
#  'ANIELA JAFFE',
#  'CLARA WINSTON',
#  'RICHARD WINSTON',
#  'DAVID BALDACCI',
#  'ROSS MACDONALD',
#  'TOM NOLAN',
#  'HART DEFOUW',
#  'SIDNEY SHELDON',
#  'NAUGHTY DOG',
#  'THOMAS HARRIS',
#  'REEMA THAREJA',
#  'PALDEN GYATSO TENZING',
#  'DANIEL SILVA',
#  'HBR',
#  'GEORGE ORWELL',
# ...

# %%
df.head(2)
# Out:
#                                  Title          Author  \
# 0  The Prisoner's Gold (The Hunters 3)  Chris Kuzneski
# 1   Guru Dutt: A Tragedy in Three Acts    Arun Khopkar
#
#                    Edition   Reviews              Ratings  \
# 0  Paperback,– 10 Mar 2016  4.000000   8 customer reviews
# 1   Paperback,– 7 Nov 2012  3.900391  14 customer reviews
#
#                                             Synopsis  \
# 0  THE HUNTERS return in their third brilliant no...
# 1  A layered portrait of a troubled genius for wh...
#
#                         Genre                          BookCategory   Price  \
# 0  Action & Adventure (Books)                    Action & Adventure  220.00
# 1  Cinema & Broadcast (Books)  Biographies, Diaries & True Accounts  202.93
#
#    Number of Ratings  Edition_1          Date  year month
# 0                  8  Paperback   10 Mar 2016  2016   MAR
# 1                 14  Paperback    7 Nov 2012  2012   NOV

# %%
def split_authors(data):
    authors=list(data)
    A1=[]
    A2=[]
    A3=[]
    A4=[]
    A5=[]
    for i in authors:
        try:
            A1.append(i.split(",")[0].strip().upper())
        except:
            A1.append("None")
        try:
            A2.append(i.split(",")[1].strip().upper())
        except:
            A2.append("None")
        try:
            A3.append(i.split(",")[2].strip().upper())
        except:
            A3.append("None")
        try:
            A4.append(i.split(",")[3].strip().upper())
        except:
            A4.append("None")
        try:
            A5.append(i.split(",")[4].strip().upper())
        except:
            A5.append("None")
    return A1,A2,A3,A4,A5
all_authors.append("None")

# %%
a1,a2,a3,a4,a5=split_authors(df["Author"])

# %%
df["Author_1"]=a1
df["Author_2"]=a2
df["Author_3"]=a3
df["Author_4"]=a4
df["Author_5"]=a5

# %%
Book_category=df["BookCategory"]

# %%
book_slice=list(Book_category)

# %%
book_cat=[i.split(",") for i in book_slice]
book_cat
# Out:
# [['Action & Adventure'],
#  ['Biographies', ' Diaries & True Accounts'],
#  ['Humour'],
#  ['Crime', ' Thriller & Mystery'],
#  ['Arts', ' Film & Photography'],
#  ['Sports'],
#  ['Crime', ' Thriller & Mystery'],
#  ['Sports'],
#  ['Biographies', ' Diaries & True Accounts'],
#  ['Action & Adventure'],
#  ['Language', ' Linguistics & Writing'],
#  ['Computing', ' Internet & Digital Media'],
#  ['Action & Adventure'],
#  ['Sports'],
#  ['Romance'],
#  ['Comics & Mangas'],
#  ['Crime', ' Thriller & Mystery'],
#  ['Comics & Mangas'],
#  ['Biographies', ' Diaries & True Accounts'],
#  ['Computing', ' Internet & Digital Media'],
#  ['Action & Adventure'],
#  ['Sports'],
#  ['Action & Adventure'],
#  ['Computing', ' Internet & Digital Media'],
#  ['Language', ' Linguistics & Writing'],
#  ['Politics'],
#  ['Sports'],
#  ['Comics & Mangas'],
#  ['Sports'],
#  ['Biographies', ' Diaries & True Accounts'],
#  ['Crime', ' Thriller & Mystery'],
#  ['Humour'],
# ...

# %%
max=1
for i in book_cat:
    if len(i)>=max:
        max=len(i)
print("Number of categories for a single book:",max)
all_categories = [cat.strip().upper() for listin in book_cat for cat in listin]
# Out:
# Number of categories for a single book: 2

# %%
def split_categories(data):
    cat=list(data)
    C1=[]
    C2=[]
    for i in cat:
        try:
            C1.append(i.split(",")[0].strip().upper())
        except:
            C1.append("None")
        try:
            C2.append(i.split(",")[1].strip().upper())
        except:
            C2.append("None")
    return C1,C2
all_categories.append("None")

# %%
c1,c2=split_categories(df["BookCategory"])

# %%
c1
# Out:
# ['ACTION & ADVENTURE',
#  'BIOGRAPHIES',
#  'HUMOUR',
#  'CRIME',
#  'ARTS',
#  'SPORTS',
#  'CRIME',
#  'SPORTS',
#  'BIOGRAPHIES',
#  'ACTION & ADVENTURE',
#  'LANGUAGE',
#  'COMPUTING',
#  'ACTION & ADVENTURE',
#  'SPORTS',
#  'ROMANCE',
#  'COMICS & MANGAS',
#  'CRIME',
#  'COMICS & MANGAS',
#  'BIOGRAPHIES',
#  'COMPUTING',
#  'ACTION & ADVENTURE',
#  'SPORTS',
#  'ACTION & ADVENTURE',
#  'COMPUTING',
#  'LANGUAGE',
#  'POLITICS',
#  'SPORTS',
#  'COMICS & MANGAS',
#  'SPORTS',
#  'BIOGRAPHIES',
#  'CRIME',
#  'HUMOUR',
#  'BIOGRAPHIES',
#  'ROMANCE',
#  'COMICS & MANGAS',
#  'CRIME',
#  'LANGUAGE',
#  'BIOGRAPHIES',
#  'CRIME',
#  'SPORTS',
#  'LANGUAGE',
#  'CRIME',
#  'LANGUAGE',
#  'LANGUAGE',
#  'ROMANCE',
#  'SPORTS',
#  'ARTS',
#  'BIOGRAPHIES',
#  'ACTION & ADVENTURE',
#  'ARTS',
#  'ACTION & ADVENTURE',
#  'BIOGRAPHIES',
#  'ARTS',
#  'CRIME',
#  'BIOGRAPHIES',
#  'HUMOUR',
#  'ROMANCE',
#  'HUMOUR',
#  'ACTION & ADVENTURE',
#  'ARTS',
#  'COMPUTING',
#  'BIOGRAPHIES',
# ...

# %%
c2
# Out:
# ['None',
#  'DIARIES & TRUE ACCOUNTS',
#  'None',
#  'THRILLER & MYSTERY',
#  'FILM & PHOTOGRAPHY',
#  'None',
#  'THRILLER & MYSTERY',
#  'None',
#  'DIARIES & TRUE ACCOUNTS',
#  'None',
#  'LINGUISTICS & WRITING',
#  'INTERNET & DIGITAL MEDIA',
#  'None',
#  'None',
#  'None',
#  'None',
#  'THRILLER & MYSTERY',
#  'None',
#  'DIARIES & TRUE ACCOUNTS',
#  'INTERNET & DIGITAL MEDIA',
#  'None',
#  'None',
#  'None',
#  'INTERNET & DIGITAL MEDIA',
#  'LINGUISTICS & WRITING',
#  'None',
#  'None',
#  'None',
#  'None',
#  'DIARIES & TRUE ACCOUNTS',
#  'THRILLER & MYSTERY',
#  'None',
#  'DIARIES & TRUE ACCOUNTS',
#  'None',
#  'None',
#  'THRILLER & MYSTERY',
#  'LINGUISTICS & WRITING',
#  'DIARIES & TRUE ACCOUNTS',
#  'THRILLER & MYSTERY',
#  'None',
#  'LINGUISTICS & WRITING',
#  'THRILLER & MYSTERY',
#  'LINGUISTICS & WRITING',
#  'LINGUISTICS & WRITING',
#  'None',
#  'None',
#  'FILM & PHOTOGRAPHY',
#  'DIARIES & TRUE ACCOUNTS',
#  'None',
#  'FILM & PHOTOGRAPHY',
#  'None',
# ...

# %%
df["Category1"]=c1
df["Category2"]=c2

# %%
genres=df["Genre"]
genre_list=genres
genre_lis=[i.split(",") for i in genre_list]

# %%
max=1
for i in genre_lis:
    if len(i)>=max:
        max=len(i)
print("Number of genres for a single category:",max)
all_genres = [cat.strip().upper() for listin in genre_lis for cat in listin]
# Out:
# Number of genres for a single category: 2

# %%
def split_genres(x):
    gen=list(x)
    D1=[]
    D2=[]
    for i in gen:
        try:
            D1.append(i.split(",")[0].strip().upper())
        except:
            D1.append("None")
        try:
            D2.append(i.split(",")[1].strip().upper())
        except:
            D2.append("None")
    return D1,D2
all_genres.append("None")

# %%
d1,d2=split_genres(df["Genre"])

# %%
df["Genre_1"]=d1
df["Genre_2"]=d2

# %%
df.tail(55)
# Out:
#                                                   Title  \
# 6182                                  The Tall Stranger
# 6183                 It Must've Been Something He Wrote
# 6184  Calvin And Hobbes Volume 2: One Day the Wind W...
# 6185                       Basic Electrical Engineering
# 6186                                  Rules of Civility
# 6187  You Are a Badass® Talking Button (Miniature Ed...
# 6188                              The Elements of Style
# 6189                         Slow Horses (Slough House)
# 6190  Tarzan: The Complete Russ Manning Newspaper St...
# 6191  Spy Secrets That Can Save Your Life: A Former ...
# 6192                                A Life in Diplomacy
# 6193         Justice League Vol. 1: Origin (The New 52)
# 6194                        English Grammar For Dummies
# 6195        Heart and Brain: An Awkward Yeti Collection
# 6196  While You Were Sleeping: A Gripping Psychologi...
# 6197     An Unquiet Mind: A memoir of moods and madness
# ...

# %%
df.drop(["Synopsis","Genre","BookCategory","Ratings","Edition","Author"],axis=1,inplace=True)

# %%
df.drop("Date",axis=1,inplace=True)

# %%
df.head(5)
# Out:
#                                         Title   Reviews   Price  \
# 0         The Prisoner's Gold (The Hunters 3)  4.000000  220.00
# 1          Guru Dutt: A Tragedy in Three Acts  3.900391  202.93
# 2                Leviathan (Penguin Classics)  4.800781  299.00
# 3          A Pocket Full of Rye (Miss Marple)  4.101562  180.00
# 4  LIFE 70 Years of Extraordinary Photography  5.000000  965.62
#
#    Number of Ratings  Edition_1  year month         Author_1 Author_2  \
# 0                  8  Paperback  2016   MAR   CHRIS KUZNESKI     None
# 1                 14  Paperback  2012   NOV     ARUN KHOPKAR     None
# 2                  6  Paperback  1982   FEB    THOMAS HOBBES     None
# 3                 13  Paperback  2017   OCT  AGATHA CHRISTIE     None
# 4                  1  Hardcover  2006   OCT  EDITORS OF LIFE     None
#
#   Author_3 Author_4 Author_5           Category1                Category2  \
# 0     None     None     None  ACTION & ADVENTURE                     None
# ...

# %%
df_test=pd.read_excel("Data_Test.xlsx")

# %%
df_test.head(5)
# Out:
#                                                Title                  Author  \
# 0         The Complete Sherlock Holmes: 2 Boxes sets  Sir Arthur Conan Doyle
# 1  Learn Docker - Fundamentals of Docker 18.x: Ev...     Gabriel N. Schenker
# 2                                           Big Girl          Danielle Steel
# 3  Think Python: How to Think Like a Computer Sci...         Allen B. Downey
# 4  Oxford Word Skills: Advanced - Idioms & Phrasa...           Redman Gairns
#
#                               Edition             Reviews  \
# 0  Mass Market Paperback,– 1 Oct 1986  4.4 out of 5 stars
# 1     Paperback,– Import, 26 Apr 2018  5.0 out of 5 stars
# 2             Paperback,– 17 Mar 2011  5.0 out of 5 stars
# 3                    Paperback,– 2016  4.1 out of 5 stars
# 4             Paperback,– 26 Dec 2011  4.4 out of 5 stars
#
#                 Ratings                                           Synopsis  \
# ...

# %%
df_test["Reviews"]=df_test["Reviews"].apply(data)

# %%
df_test["Reviews"]=df_test["Reviews"].astype("float16")

# %%
df_test["Number of Ratings"]=df_test["Ratings"].apply(data_1)
df_test["Edition_1"]=df_test["Edition"].apply(extract)
ratings_test=list(df_test["Number of Ratings"])
plu=","
ratings_test=[int(re.sub(",","",i).strip()) for i in ratings_test]
editions_1=list(df_test["Edition"])

# %%
df_test["Edition"].head(5)
# Out:
# 0    Mass Market Paperback,– 1 Oct 1986
# 1       Paperback,– Import, 26 Apr 2018
# 2               Paperback,– 17 Mar 2011
# 3                      Paperback,– 2016
# 4               Paperback,– 26 Dec 2011
# Name: Edition, dtype: object

# %%
df_test["Date"]=df_test['Edition'].str.split(",– ").str[1].str.strip()

# %%
df_test.head(2)
# Out:
#                                                Title                  Author  \
# 0         The Complete Sherlock Holmes: 2 Boxes sets  Sir Arthur Conan Doyle
# 1  Learn Docker - Fundamentals of Docker 18.x: Ev...     Gabriel N. Schenker
#
#                               Edition   Reviews               Ratings  \
# 0  Mass Market Paperback,– 1 Oct 1986  4.398438  960 customer reviews
# 1     Paperback,– Import, 26 Apr 2018  5.000000     1 customer review
#
#                                             Synopsis  \
# 0  A collection of entire body of work of the She...
# 1  Enhance your software deployment workflow usin...
#
#                          Genre                         BookCategory  \
# 0        Short Stories (Books)            Crime, Thriller & Mystery
# 1  Operating Systems Textbooks  Computing, Internet & Digital Media
#
#   Number of Ratings              Edition_1                 Date
# 0               960  Mass Market Paperback           1 Oct 1986
# ...

# %%
df_test["year"]=df_test["Date"].str.split(" ").str[-1].str.strip()

# %%
df_test["month"]=df_test["Date"].str.split(" ").str[-2].str.strip()

# %%
a1,a2,a3,a4,a5=split_authors(df_test["Author"])

# %%
df_test["Author_1"]=a1
df_test["Author_2"]=a2
df_test["Author_3"]=a3
df_test["Author_4"]=a4
df_test["Author_5"]=a5

# %%
c1,c2=split_categories(df_test["BookCategory"])

# %%
df_test["Category1"]=c1
df_test["Category2"]=c2

# %%
d1,d2=split_genres(df_test["Genre"])
df_test["Genre_1"]=d1
df_test["Genre_2"]=d2

# %%
df_test.head(2)
# Out:
#                                                Title                  Author  \
# 0         The Complete Sherlock Holmes: 2 Boxes sets  Sir Arthur Conan Doyle
# 1  Learn Docker - Fundamentals of Docker 18.x: Ev...     Gabriel N. Schenker
#
#                               Edition   Reviews               Ratings  \
# 0  Mass Market Paperback,– 1 Oct 1986  4.398438  960 customer reviews
# 1     Paperback,– Import, 26 Apr 2018  5.000000     1 customer review
#
#                                             Synopsis  \
# 0  A collection of entire body of work of the She...
# 1  Enhance your software deployment workflow usin...
#
#                          Genre                         BookCategory  \
# 0        Short Stories (Books)            Crime, Thriller & Mystery
# 1  Operating Systems Textbooks  Computing, Internet & Digital Media
#
#   Number of Ratings              Edition_1  ... month                Author_1  \
# ...

# %%
df_test.drop(["Synopsis","Genre","BookCategory","Ratings","Edition","Author"],axis=1,inplace=True)

# %%
df_test
# Out:
#                                                   Title   Reviews  \
# 0            The Complete Sherlock Holmes: 2 Boxes sets  4.398438
# 1     Learn Docker - Fundamentals of Docker 18.x: Ev...  5.000000
# 2                                              Big Girl  5.000000
# 3     Think Python: How to Think Like a Computer Sci...  4.101562
# 4     Oxford Word Skills: Advanced - Idioms & Phrasa...  4.398438
# ...                                                 ...       ...
# 1555  100 Things Every Designer Needs to Know About ...  5.000000
# 1556  Modern Letter Writing Course: Personal, Busine...  3.599609
# 1557                      The Kite Runner Graphic Novel  4.000000
# 1558    Panzer Leader (Penguin World War II Collection)  3.500000
# 1559                      Complete Spanish Step-by-Step  4.500000
#
#      Number of Ratings              Edition_1                 Date  year  \
# 0                  960  Mass Market Paperback           1 Oct 1986  1986
# ...

# %%
df_test.drop("Date",axis=1,inplace=True)

# %%
df_test["year"]=df_test["year"].apply(remove_unnecessary)

# %%
df_test["month"]=df_test["month"].apply(remove_text)

# %%
X=df.drop("Price",axis=1)

# %%
y=df["Price"].values

# %%
def unique_items(list1, list2):
    a = list1
    b = list2
    a.extend(b)
    return list(set(a))

# %%
from sklearn.preprocessing import LabelEncoder
le_Title=LabelEncoder()
all_titles = unique_items(list(X.Title),list(df_test.Title))
le_Title.fit(all_titles)

le_Edition_Type = LabelEncoder()
all_etypes = unique_items(list(X.Edition_1),list(df_test.Edition_1))
le_Edition_Type.fit(all_etypes)


le_Edition_Month = LabelEncoder()
all_em = unique_items(list(X.month),list(df_test.month))
le_Edition_Month.fit(all_em)

le_Author = LabelEncoder()
all_Authors = list(set(all_authors))
le_Author.fit(all_Authors)


le_Genre = LabelEncoder()
all_Genres = list(set(all_genres))
le_Genre.fit(all_Genres)

le_Category = LabelEncoder()
all_Categories = list(set(all_categories))
le_Category.fit(all_Categories)
# Out:
# LabelEncoder()

# %%
X["Title"]=le_Title.transform(X['Title'])
X['Edition_1'] = le_Edition_Type.transform(X['Edition_1'])
X['month'] = le_Edition_Month.transform(X['month'])

# %%
X['Author_1'] = le_Author.transform(X['Author_1'])
X['Author_2'] = le_Author.transform(X['Author_2'])
X['Author_3'] = le_Author.transform(X['Author_3'])
X['Author_4'] = le_Author.transform(X['Author_4'])
X['Author_5'] = le_Author.transform(X['Author_5'])

# %%
X['Category1'] = le_Category.transform(X['Category1'])
X['Category2'] = le_Category.transform(X['Category2'])

# %%
X['Genre_1'] = le_Genre.transform(X['Genre_1'])
X['Genre_2'] = le_Genre.transform(X['Genre_2'])

# %%
df_test['Category1'] = le_Category.transform(df_test['Category1'])
df_test['Category2'] = le_Category.transform(df_test['Category2'])

# %%
df_test['Edition_1'] = le_Edition_Type.transform(df_test['Edition_1'])

# %%
df_test['Title'] = le_Title.transform(df_test['Title'])

# %%
df_test['month'] = le_Edition_Month.transform(df_test['month'])

# %%
df_test["Author_1"]=le_Author.fit_transform(df_test["Author_1"])
df_test["Author_2"]=le_Author.fit_transform(df_test["Author_2"])
df_test["Author_3"]=le_Author.fit_transform(df_test["Author_3"])
df_test["Author_4"]=le_Author.fit_transform(df_test["Author_4"])
df_test["Author_5"]=le_Author.fit_transform(df_test["Author_5"])

# %%
df_test['Genre_1'] = le_Genre.fit_transform(df_test['Genre_1'])
df_test['Genre_2'] = le_Genre.fit_transform(df_test['Genre_2'])

# %%
df_test.head(55)
# Out:
#     Title   Reviews Number of Ratings  Edition_1  year  month  Author_1  \
# 0    5087  4.398438               960         12  1986     11      1060
# 1    2907  5.000000                 1         13  2018      0       350
# 2     753  5.000000                 4         13  2011      7       234
# 3    6233  4.101562                11         13  2016      9        43
# 4    3787  4.398438                 9         13  2011      2       924
# 5    6448  5.000000                 2         13  2013     10       509
# 6    1261  5.000000                 1         13  2019      3       939
# 7     100  4.300781               117         13  2012      7       368
# 8     428  4.398438               550          8  2016     11      1040
# 9    1470  4.398438                 6         13  2019      7       872
# 10   1186  3.300781                12         13  2018     12      1191
# 11    203  5.000000                 1         13  2017      5       715
# ...

# %%
X["year"]=X["year"].apply(remove_unnecessary)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X=sc.fit_transform(X)

# %%
y=y.reshape((len(y),1))
y=y.ravel()

# %%
ratings_test=list(df_test["Number of Ratings"])
plu=","
ratings_test=[int(re.sub(",","",i).strip()) for i in ratings_test]

# %%
df_test["Number of Ratings"]=ratings_test

# %%
df_test["Number of Ratings"]=pd.to_numeric(df_test["Number of Ratings"])

# %%
df_test=sc.fit_transform(df_test)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X,y, test_size = 0.3, random_state = 101)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
# Out:
# 570.3646729401833

# %%
X.shape
# Out:
# (6237, 15)

# %%
y.shape
# Out:
# (6237,)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
# Out:
# (4365, 15)
# (4365,)
# (1872, 15)
# (1872,)

# %%
predict=lr.predict(X_val)

# %%
from sklearn import metrics

# %%
print("MAE:",metrics.mean_absolute_error(y_val,predict))
# Out:
# MAE: 325.37593743488077

# %%
print("MSE:",metrics.mean_squared_error(y_val,predict))
# Out:
# MSE: 319399.2014811247

# %%
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_val,predict)))
# Out:
# RMSE: 565.1541395770934

# %%
predicting=lr.predict(df_test)

# %%
Submission=pd.DataFrame({"Price":predicting})

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(X_train,y_train)
predict_1=svr.predict(X_val)

# %%
metrics.mean_absolute_error(y_val,predict_1)
# Out:
# 283.0468592938273

# %%
metrics.mean_squared_error(y_val,predict_1)
# Out:
# 356439.520608939

# %%
np.sqrt(metrics.mean_squared_error(y_val,predict_1))
# Out:
# 597.0255611018166

# %%
Predicting=svr.predict(df_test)

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()

# %%
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
predict_2=dtr.predict(X_val)

# %%
print(metrics.mean_absolute_error(y_val,predict_2))
# Out:
# 388.6222676282051

# %%
metrics.mean_squared_error(y_val,predict_2)
# Out:
# 678194.6305609376

# %%
np.sqrt(metrics.mean_squared_error(y_val,predict_2))
# Out:
# 823.525731571842

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(n_estimators=1000,random_state=101)
rfr.fit(X_train,y_train)
predict_3=rfr.predict(X_val)
print(metrics.mean_absolute_error(y_val,predict_3))
print(metrics.mean_squared_error(y_val,predict_3))
print(np.sqrt(metrics.mean_squared_error(y_val,predict_3)))
# Out:
# 293.0004844866665
# 295215.2358220617
# 543.3371290663483

# %%
from sklearn.ensemble import GradientBoostingRegressor
abc=GradientBoostingRegressor(n_estimators=100,random_state=101,max_depth=6,alpha=0.1)
abc.fit(X_train,y_train)
predict_4=abc.predict(X_val)
print(metrics.mean_absolute_error(y_val,predict_4))
print(metrics.mean_squared_error(y_val,predict_4))
print(np.sqrt(metrics.mean_squared_error(y_val,predict_4)))
# Out:
# 292.18245330894445
# 301441.54150614823
# 549.0369218059458

# %%
from xgboost import XGBRegressor

# %%
xgb=XGBRegressor()

# %%
xgb.fit(X_train,y_train)
# Out:
# [20:50:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()

# %%
predict_6=xgb.predict(X_val)

# %%
metrics.mean_absolute_error(y_val,predict_6)
# Out:
# 288.94222233503297

# %%
metrics.mean_squared_error(y_val,predict_6)
# Out:
# 285389.1921379374

# %%
np.sqrt(metrics.mean_squared_error(y_val,predict_6))
# Out:
# 534.2183000777279

# %%
#Stacking

# %%
level_0=[(("xgb",XGBRegressor(learning_rate=0.01, n_estimators=1000))),(("rfr",RandomForestRegressor())),(("abc",GradientBoostingRegressor()))]

# %%
from sklearn.ensemble import StackingRegressor

# %%
sr=StackingRegressor(estimators=level_0,final_estimator=LinearRegression(),cv=10)

# %%
sr.fit(X_train,y_train)
# Out:
# [20:50:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:50:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:50:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:50:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:50:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:50:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:50:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:50:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
predict_stacking=sr.predict(X_val)

# %%
metrics.mean_absolute_error(y_val,predict_stacking)
# Out:
# 281.73569109293373

# %%
metrics.mean_squared_error(y_val,predict_stacking)
# Out:
# 278189.2596345048

# %%
np.sqrt(metrics.mean_squared_error(y_val,predict_stacking))
# Out:
# 527.4364982009728

# %%
parameters= {"learning_rate"    : [0.04,0.05,0.06 ] ,
             'n_estimators': range(500, 5000, 500),
 "max_depth": [7,8,9],
 "min_child_weight" : [5, 7, 9 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.4, 0.5 , 0.7 ] }

# %%
Predicting=xgb.predict(df_test)

# %%
param_grid = { 
    'n_estimators': [200, 700],
    'max_features': ['auto', 'sqrt', 'log2']
}
search_random = {'n_estimators': range(1000, 5000, 500),'learning_rate':[0.001,0.01,0.02]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid=GridSearchCV(xgb,search_random,verbose=1,cv=5,n_jobs=-1)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [21:39:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# GridSearchCV(cv=5, estimator=XGBRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.001, 0.01, 0.02],
#                          'n_estimators': range(1000, 5000, 500)},
#              verbose=1)

# %%
grid.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 1000}

# %%
predict_5=grid.predict(X_val)

# %%
metrics.mean_absolute_error(y_val,predict_5)
# Out:
# 287.6826584605682

# %%
metrics.mean_squared_error(y_val,predict_5)
# Out:
# 286142.566804055

# %%
np.sqrt(metrics.mean_squared_error(y_val,predict_5))
# Out:
# 534.9229540822257

# %%
Predicting_1=grid.predict(df_test)

# %%
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits

# %%
Submission=pd.DataFrame({"Price":Predicting_1})

# %%
Submission
# Out:
#            Price
# 0     400.154022
# 1     834.128296
# 2     495.031189
# 3     671.094604
# 4     399.220306
# ...          ...
# 1555  759.946655
# 1556  313.661377
# 1557  425.507904
# 1558  403.700836
# 1559  506.077667
#
# [1560 rows x 1 columns]

# %%
Submission.to_csv("Submission.csv",index=False)
